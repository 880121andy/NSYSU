# %% [markdown]
# <a href="https://colab.research.google.com/github/880121andy/NSYSU/blob/main/EX03-02%20%E5%85%AC%E5%8F%B8%E8%96%AA%E8%B3%87%E6%A6%82%E6%B3%81%E2%85%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 22, 29, 38, 27, 33, 31],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'Salary': [50000, 60000, 75000, 80000, 45000, 62000, 72000, 58000, 69000, 71000],
    'Department': ['IT', 'HR', 'Finance', 'Marketing', 'IT', 'HR', 'Finance', 'Marketing', 'IT', 'Finance']
}

df = pd.DataFrame(data)
print(df)
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %% [markdown]
# ### 將薪水高於第3四分位數的人員標示為高薪

# %%
hs = df['Salary'].quantile(0.75)
hs
# Out:
# np.float64(71750.0)

# %%
df['HighSalary'] = df['Salary'].apply(lambda x: True if x > hs else False)
df
# Out:
#     ID     Name  Age          City  Salary Department  HighSalary
# 0  101    Alice   25      New York   50000         IT       False
# 1  102      Bob   30   Los Angeles   60000         HR       False
# 2  103  Charlie   35       Chicago   75000    Finance        True
# 3  104    David   40       Houston   80000  Marketing        True
# 4  105      Eve   22       Phoenix   45000         IT       False
# 5  106    Frank   29  Philadelphia   62000         HR       False
# 6  107    Grace   38   San Antonio   72000    Finance        True
# 7  108    Helen   27     San Diego   58000  Marketing       False
# 8  109      Ivy   33        Dallas   69000         IT       False
# 9  110     Jack   31      San Jose   71000    Finance       False

# %%
df[df['HighSalary']]
# Out:
#     ID     Name  Age         City  Salary Department  HighSalary
# 2  103  Charlie   35      Chicago   75000    Finance        True
# 3  104    David   40      Houston   80000  Marketing        True
# 6  107    Grace   38  San Antonio   72000    Finance        True

# %% [markdown]
# ### 刪除高薪欄位

# %%
df.drop(columns=['HighSalary'], inplace=True) #inplace為取代原來的df
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %% [markdown]
# ### 使用 pd.concat() 新增資料 (合併兩個資料集)

# %%
new_data = [
    {'ID': 111, 'Name': 'Kevin', 'Age': 28, 'City': 'Austin', 'Salary': None, 'Department': 'IT'},
    {'ID': 112, 'Name': 'Lily', 'Age': 26, 'City': 'Seattle', 'Salary': 55000, 'Department': 'Marketing'},
    {'ID': 112, 'Name': 'Lily', 'Age': 26, 'City': 'Seattle', 'Salary': 55000, 'Department': 'Marketing'}
]

new_df = pd.DataFrame(new_data)
new_df
# Out:
#     ID   Name  Age     City   Salary Department
# 0  111  Kevin   28   Austin      NaN         IT
# 1  112   Lily   26  Seattle  55000.0  Marketing
# 2  112   Lily   26  Seattle  55000.0  Marketing

# %%
df = pd.concat([df, new_df], ignore_index=True) #ignore_index是讓兩個dataframe的index不要重複
df
# Out:
#      ID     Name  Age          City   Salary Department
# 0   101    Alice   25      New York  50000.0         IT
# 1   102      Bob   30   Los Angeles  60000.0         HR
# 2   103  Charlie   35       Chicago  75000.0    Finance
# 3   104    David   40       Houston  80000.0  Marketing
# 4   105      Eve   22       Phoenix  45000.0         IT
# 5   106    Frank   29  Philadelphia  62000.0         HR
# 6   107    Grace   38   San Antonio  72000.0    Finance
# 7   108    Helen   27     San Diego  58000.0  Marketing
# 8   109      Ivy   33        Dallas  69000.0         IT
# 9   110     Jack   31      San Jose  71000.0    Finance
# 10  111    Kevin   28        Austin      NaN         IT
# 11  112     Lily   26       Seattle  55000.0  Marketing
# 12  112     Lily   26       Seattle  55000.0  Marketing

# %% [markdown]
# ### 找出空值的資料列，並填充空值（薪水依該部門平均值）

# %%
df.isnull().sum()
# Out:
# ID            0
# Name          0
# Age           0
# City          0
# Salary        1
# Department    0
# dtype: int64

# %%
avg_dp = df.groupby('Department')['Salary'].mean() #計算每個部份的平均薪水
avg_dp
# Out:
# Department
# Finance      72666.666667
# HR           61000.000000
# IT           54666.666667
# Marketing    62000.000000
# Name: Salary, dtype: float64

# %%
for i in range(len(df)):
  if pd.isnull(df.loc[i, 'Salary']):
    df.loc[i, 'Salary'] = avg_dp[df.loc[i, 'Department']]

df
# Out:
#      ID     Name  Age          City        Salary Department
# 0   101    Alice   25      New York  50000.000000         IT
# 1   102      Bob   30   Los Angeles  60000.000000         HR
# 2   103  Charlie   35       Chicago  75000.000000    Finance
# 3   104    David   40       Houston  80000.000000  Marketing
# 4   105      Eve   22       Phoenix  45000.000000         IT
# 5   106    Frank   29  Philadelphia  62000.000000         HR
# 6   107    Grace   38   San Antonio  72000.000000    Finance
# 7   108    Helen   27     San Diego  58000.000000  Marketing
# 8   109      Ivy   33        Dallas  69000.000000         IT
# 9   110     Jack   31      San Jose  71000.000000    Finance
# 10  111    Kevin   28        Austin  54666.666667         IT
# 11  112     Lily   26       Seattle  55000.000000  Marketing
# 12  112     Lily   26       Seattle  55000.000000  Marketing

# %% [markdown]
# ### 刪除重複資料

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      ID     Name  Age          City        Salary Department
# 0   101    Alice   25      New York  50000.000000         IT
# 1   102      Bob   30   Los Angeles  60000.000000         HR
# 2   103  Charlie   35       Chicago  75000.000000    Finance
# 3   104    David   40       Houston  80000.000000  Marketing
# 4   105      Eve   22       Phoenix  45000.000000         IT
# 5   106    Frank   29  Philadelphia  62000.000000         HR
# 6   107    Grace   38   San Antonio  72000.000000    Finance
# 7   108    Helen   27     San Diego  58000.000000  Marketing
# 8   109      Ivy   33        Dallas  69000.000000         IT
# 9   110     Jack   31      San Jose  71000.000000    Finance
# 10  111    Kevin   28        Austin  54666.666667         IT
# 11  112     Lily   26       Seattle  55000.000000  Marketing

# %% [markdown]
# ### 新增欄位 'NewSalary'，如果薪水小於平均值則薪水加 500，否則維持原薪水；新增欄位 'RankSalary' 填入薪水排名

# %%
df['NewSalary'] = df['Salary'].apply(lambda x: x + 500 if x < df['Salary'].mean() else x)
df
# Out:
#      ID     Name  Age          City        Salary Department     NewSalary
# 0   101    Alice   25      New York  50000.000000         IT  50500.000000
# 1   102      Bob   30   Los Angeles  60000.000000         HR  60500.000000
# 2   103  Charlie   35       Chicago  75000.000000    Finance  75000.000000
# 3   104    David   40       Houston  80000.000000  Marketing  80000.000000
# 4   105      Eve   22       Phoenix  45000.000000         IT  45500.000000
# 5   106    Frank   29  Philadelphia  62000.000000         HR  62500.000000
# 6   107    Grace   38   San Antonio  72000.000000    Finance  72000.000000
# 7   108    Helen   27     San Diego  58000.000000  Marketing  58500.000000
# 8   109      Ivy   33        Dallas  69000.000000         IT  69000.000000
# 9   110     Jack   31      San Jose  71000.000000    Finance  71000.000000
# 10  111    Kevin   28        Austin  54666.666667         IT  55166.666667
# ...

# %%
df['RankSalary'] = df['Salary'].rank(ascending=False)
df
# Out:
#      ID     Name  Age          City        Salary Department     NewSalary  \
# 0   101    Alice   25      New York  50000.000000         IT  50500.000000
# 1   102      Bob   30   Los Angeles  60000.000000         HR  60500.000000
# 2   103  Charlie   35       Chicago  75000.000000    Finance  75000.000000
# 3   104    David   40       Houston  80000.000000  Marketing  80000.000000
# 4   105      Eve   22       Phoenix  45000.000000         IT  45500.000000
# 5   106    Frank   29  Philadelphia  62000.000000         HR  62500.000000
# 6   107    Grace   38   San Antonio  72000.000000    Finance  72000.000000
# 7   108    Helen   27     San Diego  58000.000000  Marketing  58500.000000
# 8   109      Ivy   33        Dallas  69000.000000         IT  69000.000000
# 9   110     Jack   31      San Jose  71000.000000    Finance  71000.000000
# 10  111    Kevin   28        Austin  54666.666667         IT  55166.666667
# ...

# %%
df[['Salary', 'NewSalary', 'RankSalary']] = df[['Salary', 'NewSalary', 'RankSalary']].astype(int) #讓float變成int，數據更容易看
df
# Out:
#      ID     Name  Age          City  Salary Department  NewSalary  RankSalary
# 0   101    Alice   25      New York   50000         IT      50500          11
# 1   102      Bob   30   Los Angeles   60000         HR      60500           7
# 2   103  Charlie   35       Chicago   75000    Finance      75000           2
# 3   104    David   40       Houston   80000  Marketing      80000           1
# 4   105      Eve   22       Phoenix   45000         IT      45500          12
# 5   106    Frank   29  Philadelphia   62000         HR      62500           6
# 6   107    Grace   38   San Antonio   72000    Finance      72000           3
# 7   108    Helen   27     San Diego   58000  Marketing      58500           8
# 8   109      Ivy   33        Dallas   69000         IT      69000           5
# 9   110     Jack   31      San Jose   71000    Finance      71000           4
# 10  111    Kevin   28        Austin   54666         IT      55166          10
# ...
